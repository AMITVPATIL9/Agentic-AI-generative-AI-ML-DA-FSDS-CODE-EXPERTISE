# %%
str('10')
# Out:
# '10'

# %%
str('ten')
# Out:
# 'ten'

# %%
str(10)
# Out:
# '10'

# %%
str(amit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 str(amit)
#
# NameError: name 'amit' is not defined

# %%
str('amit')
# Out:
# 'amit'

# %%
str(True)
# Out:
# 'True'

# %%
str('False')
# Out:
# 'False'

# %%
str(12j)
# Out:
# '12j'

# %%
str(0+4j)
# Out:
# '4j'

# %%
str(42+25j)
# Out:
# '(42+25j)'

# %%
str('5+2j')
# Out:
# '5+2j'

# %%
str(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 str(a,b)
#
# NameError: name 'a' is not defined

# %%
str()
# Out:
# ''

# %%
bool(False)
# Out:
# False

# %%
bool(8)
# Out:
# True

# %%
bool(8.5)
# Out:
# True

# %%
bool(1)
# Out:
#   Cell In[26], line 1
#     bool(1)bool(1+2j)
#            ^
# SyntaxError: invalid syntax

# %%
bool('0')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(0)
# Out:
# 0j

# %%
comlex('ten')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 comlex('ten')
#
# NameError: name 'comlex' is not defined

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(0+10)
# Out:
# (10+0j)

# %%
complex(2+5)
# Out:
# (7+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False,True)
# Out:
# 1j
